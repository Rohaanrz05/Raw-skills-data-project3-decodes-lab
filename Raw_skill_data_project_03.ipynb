# %%
import pandas as pd

# Create a sample raw_skills dataset mapping roles to typical skill sets
skills_data = {
    'role': ['Data Scientist', 'DevOps Engineer', 'Backend Developer', 'Frontend Developer', 'Cloud Architect'],
    'skills': [
        'Python SQL Machine Learning Data Analysis Statistics Pandas Tech',
        'AWS Docker Kubernetes Git CI/CD Automation Linux Systems Tech',
        'Java Python SQL APIs Databases Django Spring Boot Tech',
        'JavaScript HTML CSS React Vue Angular Web UI UX Design Tech',
        'AWS Cloud Azure GCP Networking Security Infrastructure Tech'
    ]
}

df_skills = pd.DataFrame(skills_data)
df_skills.to_csv('raw_skills.csv', index=False)
print("✅ 'raw_skills.csv' created successfully.")
# Out:
# ✅ 'raw_skills.csv' created successfully.
